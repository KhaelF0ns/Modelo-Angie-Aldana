# %% [markdown]
# # Import

# %%
import sys

if 'seaborn' not in sys.modules:
    # %pip install seaborn

if 'pytorch-lightning' not in sys.modules:
    # %pip install pytorch-lightning

if 'plotly' not in sys.modules:
    # %pip install plotly

if 'nltk' not in sys.modules:
    # %pip install nltk

if 'unidecode' not in sys.modules:
    # %pip install unidecode

if 'scikit-learn' not in sys.modules:
    # %pip install scikit-learn

if 'pycaret' not in sys.modules:
	# %pip install pycaret==2.3.10
# Out:
# Requirement already satisfied: seaborn in ./myenv/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in ./myenv/lib/python3.10/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in ./myenv/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in ./myenv/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pillow>=6.2.0 in ./myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.4)
# Requirement already satisfied: cycler>=0.10 in ./myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in ./myenv/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in ./myenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pytorch-lightning in ./myenv/lib/python3.10/site-packages (2.0.2)
# Requirement already satisfied: tqdm>=4.57.0 in ./myenv/lib/python3.10/site-packages (from pytorch-lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in ./myenv/lib/python3.10/site-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: numpy>=1.17.2 in ./myenv/lib/python3.10/site-packages (from pytorch-lightning) (1.23.5)
# Requirement already satisfied: torchmetrics>=0.7.0 in ./myenv/lib/python3.10/site-packages (from pytorch-lightning) (0.11.4)
# Requirement already satisfied: packaging>=17.1 in ./myenv/lib/python3.10/site-packages (from pytorch-lightning) (23.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./myenv/lib/python3.10/site-packages (from pytorch-lightning) (4.5.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in ./myenv/lib/python3.10/site-packages (from pytorch-lightning) (2023.5.0)
# Requirement already satisfied: torch>=1.11.0 in ./myenv/lib/python3.10/site-packages (from pytorch-lightning) (2.0.1)
# Requirement already satisfied: lightning-utilities>=0.7.0 in ./myenv/lib/python3.10/site-packages (from pytorch-lightning) (0.8.0)
# Requirement already satisfied: requests in ./myenv/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.28.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./myenv/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.4)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (2.14.3)
# Requirement already satisfied: networkx in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (3.1)
# Requirement already satisfied: filelock in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (3.12.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (11.7.101)
# Requirement already satisfied: triton==2.0.0 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (2.0.0)
# Requirement already satisfied: jinja2 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (11.7.99)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (10.9.0.58)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (11.7.4.91)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (11.7.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (11.4.0.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (11.10.3.66)
# Requirement already satisfied: sympy in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (1.12)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (10.2.10.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./myenv/lib/python3.10/site-packages (from torch>=1.11.0->pytorch-lightning) (11.7.99)
# Requirement already satisfied: wheel in ./myenv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11.0->pytorch-lightning) (0.40.0)
# Requirement already satisfied: setuptools in ./myenv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11.0->pytorch-lightning) (59.6.0)
# Requirement already satisfied: cmake in ./myenv/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (3.26.3)
# Requirement already satisfied: lit in ./myenv/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (16.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in ./myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./myenv/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->pytorch-lightning) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./myenv/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in ./myenv/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./myenv/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in ./myenv/lib/python3.10/site-packages (from sympy->torch>=1.11.0->pytorch-lightning) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: plotly in ./myenv/lib/python3.10/site-packages (5.14.1)
# Requirement already satisfied: tenacity>=6.2.0 in ./myenv/lib/python3.10/site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in ./myenv/lib/python3.10/site-packages (from plotly) (23.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nltk in ./myenv/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in ./myenv/lib/python3.10/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in ./myenv/lib/python3.10/site-packages (from nltk) (2023.5.5)
# Requirement already satisfied: tqdm in ./myenv/lib/python3.10/site-packages (from nltk) (4.65.0)
# Requirement already satisfied: joblib in ./myenv/lib/python3.10/site-packages (from nltk) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: unidecode in ./myenv/lib/python3.10/site-packages (1.3.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in ./myenv/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in ./myenv/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in ./myenv/lib/python3.10/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in ./myenv/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./myenv/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting pycaret==2.3.10
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# Collecting pyyaml<6.0.0
#   Using cached PyYAML-5.4.1.tar.gz (175 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: scikit-plot in ./myenv/lib/python3.10/site-packages (from pycaret==2.3.10) (0.3.7)
# Requirement already satisfied: pandas in ./myenv/lib/python3.10/site-packages (from pycaret==2.3.10) (1.5.3)
# Requirement already satisfied: matplotlib in ./myenv/lib/python3.10/site-packages (from pycaret==2.3.10) (3.7.1)
# Collecting numba<0.55
#   Using cached numba-0.51.2.tar.gz (2.1 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in ./myenv/lib/python3.10/site-packages (from pycaret==2.3.10) (3.8.1)
# Requirement already satisfied: seaborn in ./myenv/lib/python3.10/site-packages (from pycaret==2.3.10) (0.12.2)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 1.6 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting cufflinks>=0.17.0
#   Using cached cufflinks-0.17.3.tar.gz (81 kB)
#   Preparing metadata (setup.py) ... done
# Collecting spacy<2.4.0
#   Using cached spacy-2.3.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
# Requirement already satisfied: IPython in ./myenv/lib/python3.10/site-packages (from pycaret==2.3.10) (8.12.0)
# Requirement already satisfied: pyod in ./myenv/lib/python3.10/site-packages (from pycaret==2.3.10) (1.0.9)
# Collecting mlflow
#   Using cached mlflow-2.3.2-py3-none-any.whl (17.7 MB)
# Collecting gensim<4.0.0
#   Using cached gensim-3.8.3.tar.gz (23.4 MB)
#   Preparing metadata (setup.py) ... done
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting scipy<=1.5.4
#   Using cached scipy-1.5.4.tar.gz (25.2 MB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [3828 lines of output]
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#       Collecting wheel
#         Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
#       Collecting setuptools
#         Using cached setuptools-67.8.0-py3-none-any.whl (1.1 MB)
#       Collecting Cython>=0.29.18
#         Using cached Cython-0.29.34-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#       Collecting numpy==1.17.3
#         Using cached numpy-1.17.3.zip (6.4 MB)
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting pybind11>=2.4.3
#         Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
#       Building wheels for collected packages: numpy
#         Building wheel for numpy (setup.py): started
#         Building wheel for numpy (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [3096 lines of output]
#             Running from numpy source directory.
#             blas_opt_info:
#             blas_mkl_info:
#             customize UnixCCompiler
#               libraries mkl_rt not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             blis_info:
#             customize UnixCCompiler
#               libraries blis not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             openblas_info:
#             customize UnixCCompiler
#             customize UnixCCompiler
#               libraries openblas not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             atlas_3_10_blas_threads_info:
#             Setting PTATLAS=ATLAS
#             customize UnixCCompiler
#               libraries tatlas not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             atlas_3_10_blas_info:
#             customize UnixCCompiler
#               libraries satlas not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             atlas_blas_threads_info:
#             Setting PTATLAS=ATLAS
#             customize UnixCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             atlas_blas_info:
#             customize UnixCCompiler
#               libraries f77blas,cblas,atlas not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             accelerate_info:
#               NOT AVAILABLE
#
#             /tmp/pip-install-dc3_t3k_/numpy_0bf5f880be2a4e7fb21a585523130e14/numpy/distutils/system_info.py:690: UserWarning:
#                 Optimized (vendor) Blas libraries are not found.
#                 Falls back to netlib Blas library which has worse performance.
#                 A better performance should be easily gained by switching
#                 Blas library.
#               self.calc_info()
#             blas_info:
#             customize UnixCCompiler
#               libraries blas not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             /tmp/pip-install-dc3_t3k_/numpy_0bf5f880be2a4e7fb21a585523130e14/numpy/distutils/system_info.py:690: UserWarning:
#                 Blas (http://www.netlib.org/blas/) libraries not found.
#                 Directories to search for the libraries can be specified in the
#                 numpy/distutils/site.cfg file (section [blas]) or by setting
#                 the BLAS environment variable.
#               self.calc_info()
#             blas_src_info:
#               NOT AVAILABLE
#
#             /tmp/pip-install-dc3_t3k_/numpy_0bf5f880be2a4e7fb21a585523130e14/numpy/distutils/system_info.py:690: UserWarning:
#                 Blas (http://www.netlib.org/blas/) sources not found.
#                 Directories to search for the sources can be specified in the
#                 numpy/distutils/site.cfg file (section [blas_src]) or by setting
#                 the BLAS_SRC environment variable.
#               self.calc_info()
#               NOT AVAILABLE
#
#             /bin/sh: 1: svnversion: not found
#             non-existing path in 'numpy/distutils': 'site.cfg'
#             lapack_opt_info:
#             lapack_mkl_info:
#             customize UnixCCompiler
#               libraries mkl_rt not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             openblas_lapack_info:
#             customize UnixCCompiler
#             customize UnixCCompiler
#               libraries openblas not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             openblas_clapack_info:
#             customize UnixCCompiler
#             customize UnixCCompiler
#               libraries openblas,lapack not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             flame_info:
#             customize UnixCCompiler
#               libraries flame not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             atlas_3_10_threads_info:
#             Setting PTATLAS=ATLAS
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /home/keos_angie/Música/music/myenv/lib
#             customize UnixCCompiler
#               libraries tatlas,tatlas not found in /home/keos_angie/Música/music/myenv/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/local/lib
#             customize UnixCCompiler
#               libraries tatlas,tatlas not found in /usr/local/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib64
#             customize UnixCCompiler
#               libraries tatlas,tatlas not found in /usr/lib64
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib
#             customize UnixCCompiler
#               libraries tatlas,tatlas not found in /usr/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#             customize UnixCCompiler
#               libraries tatlas,tatlas not found in /usr/lib/x86_64-linux-gnu
#             <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#               NOT AVAILABLE
#
#             atlas_3_10_info:
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /home/keos_angie/Música/music/myenv/lib
#             customize UnixCCompiler
#               libraries satlas,satlas not found in /home/keos_angie/Música/music/myenv/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/local/lib
#             customize UnixCCompiler
#               libraries satlas,satlas not found in /usr/local/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib64
#             customize UnixCCompiler
#               libraries satlas,satlas not found in /usr/lib64
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib
#             customize UnixCCompiler
#               libraries satlas,satlas not found in /usr/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#             customize UnixCCompiler
#               libraries satlas,satlas not found in /usr/lib/x86_64-linux-gnu
#             <class 'numpy.distutils.system_info.atlas_3_10_info'>
#               NOT AVAILABLE
#
#             atlas_threads_info:
#             Setting PTATLAS=ATLAS
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /home/keos_angie/Música/music/myenv/lib
#             customize UnixCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in /home/keos_angie/Música/music/myenv/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/local/lib
#             customize UnixCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in /usr/local/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib64
#             customize UnixCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in /usr/lib64
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib
#             customize UnixCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in /usr/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#             customize UnixCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in /usr/lib/x86_64-linux-gnu
#             <class 'numpy.distutils.system_info.atlas_threads_info'>
#               NOT AVAILABLE
#
#             atlas_info:
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /home/keos_angie/Música/music/myenv/lib
#             customize UnixCCompiler
#               libraries f77blas,cblas,atlas not found in /home/keos_angie/Música/music/myenv/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/local/lib
#             customize UnixCCompiler
#               libraries f77blas,cblas,atlas not found in /usr/local/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib64
#             customize UnixCCompiler
#               libraries f77blas,cblas,atlas not found in /usr/lib64
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib
#             customize UnixCCompiler
#               libraries f77blas,cblas,atlas not found in /usr/lib
#             customize UnixCCompiler
#               libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#             customize UnixCCompiler
#               libraries f77blas,cblas,atlas not found in /usr/lib/x86_64-linux-gnu
#             <class 'numpy.distutils.system_info.atlas_info'>
#               NOT AVAILABLE
#
#             lapack_info:
#             customize UnixCCompiler
#               libraries lapack not found in ['/home/keos_angie/Música/music/myenv/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             /tmp/pip-install-dc3_t3k_/numpy_0bf5f880be2a4e7fb21a585523130e14/numpy/distutils/system_info.py:1712: UserWarning:
#                 Lapack (http://www.netlib.org/lapack/) libraries not found.
#                 Directories to search for the libraries can be specified in the
#                 numpy/distutils/site.cfg file (section [lapack]) or by setting
#                 the LAPACK environment variable.
#               if getattr(self, '_calc_info_{}'.format(lapack))():
#             lapack_src_info:
#               NOT AVAILABLE
#
#             /tmp/pip-install-dc3_t3k_/numpy_0bf5f880be2a4e7fb21a585523130e14/numpy/distutils/system_info.py:1712: UserWarning:
#                 Lapack (http://www.netlib.org/lapack/) sources not found.
#                 Directories to search for the sources can be specified in the
#                 numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#                 the LAPACK_SRC environment variable.
#               if getattr(self, '_calc_info_{}'.format(lapack))():
#               NOT AVAILABLE
#
#             /usr/lib/python3.10/distutils/dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#               warnings.warn(msg)
#             running bdist_wheel
#             running build
#             running config_cc
#             unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#             running config_fc
#             unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#             running build_src
#             build_src
#             building py_modules sources
#             creating build
#             creating build/src.linux-x86_64-3.1
#             creating build/src.linux-x86_64-3.1/numpy
#             creating build/src.linux-x86_64-3.1/numpy/distutils
#             building library "npymath" sources
#             get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
#             customize Gnu95FCompiler
#             Could not locate executable gfortran
#             Could not locate executable f95
#             customize IntelFCompiler
#             Could not locate executable ifort
#             Could not locate executable ifc
#             customize LaheyFCompiler
#             Could not locate executable lf95
#             customize PGroupFCompiler
#             Could not locate executable pgfortran
#             customize AbsoftFCompiler
#             Could not locate executable f90
#             Could not locate executable f77
#             customize NAGFCompiler
#             customize VastFCompiler
#             customize CompaqFCompiler
#             Could not locate executable fort
#             customize IntelItaniumFCompiler
#             Could not locate executable efort
#             Could not locate executable efc
#             customize IntelEM64TFCompiler
#             customize GnuFCompiler
#             Could not locate executable g77
#             customize G95FCompiler
#             Could not locate executable g95
#             customize PathScaleFCompiler
#             Could not locate executable pathf95
#             customize NAGFORCompiler
#             Could not locate executable nagfor
#             don't know how to compile Fortran code on platform 'posix'
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             x86_64-linux-gnu-gcc _configtest.o -o _configtest
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d _configtest
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 1 | int exp (void);
#                   |     ^~~
#             _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#               +++ |+#include <math.h>
#                 1 | int exp (void);
#             x86_64-linux-gnu-gcc _configtest.o -o _configtest
#             /usr/bin/ld: _configtest.o: en la función `main':
#             /tmp/pip-install-dc3_t3k_/numpy_0bf5f880be2a4e7fb21a585523130e14/_configtest.c:6: referencia a `exp' sin definir
#             collect2: error: ld returned 1 exit status
#             failure.
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 1 | int exp (void);
#                   |     ^~~
#             _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#               +++ |+#include <math.h>
#                 1 | int exp (void);
#             x86_64-linux-gnu-gcc _configtest.o -lm -o _configtest
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d _configtest
#             creating build/src.linux-x86_64-3.1/numpy/core
#             creating build/src.linux-x86_64-3.1/numpy/core/src
#             creating build/src.linux-x86_64-3.1/numpy/core/src/npymath
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_internal.h
#               adding 'build/src.linux-x86_64-3.1/numpy/core/src/npymath' to include_dirs.
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/ieee754.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_complex.c
#             None - nothing done with h_files = ['build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_internal.h']
#             building library "npysort" sources
#             creating build/src.linux-x86_64-3.1/numpy/core/src/common
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_sort.h
#               adding 'build/src.linux-x86_64-3.1/numpy/core/src/common' to include_dirs.
#             creating build/src.linux-x86_64-3.1/numpy/core/src/npysort
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/quicksort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/mergesort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/timsort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/heapsort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/radixsort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_partition.h
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/selection.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_binsearch.h
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/binsearch.c
#             None - nothing done with h_files = ['build/src.linux-x86_64-3.1/numpy/core/src/common/npy_sort.h', 'build/src.linux-x86_64-3.1/numpy/core/src/common/npy_partition.h', 'build/src.linux-x86_64-3.1/numpy/core/src/common/npy_binsearch.h']
#             building extension "numpy.core._dummy" sources
#             Generating build/src.linux-x86_64-3.1/numpy/core/include/numpy/config.h
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c:1:10: fatal error: sys/endian.h: No existe el archivo o el directorio
#                 1 | #include <sys/endian.h>
#                   |          ^~~~~~~~~~~~~~
#             compilation terminated.
#             failure.
#             removing: _configtest.c _configtest.o
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 4)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 16)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:7:12: error: ‘SIZEOF_LONGDOUBLE’ undeclared (first use in this function); did you mean ‘SIZEOF_LONG_DOUBLE’?
#                 7 |     (void) SIZEOF_LONGDOUBLE;
#                   |            ^~~~~~~~~~~~~~~~~
#                   |            SIZEOF_LONG_DOUBLE
#             _configtest.c:7:12: note: each undeclared identifier is reported only once for each function it appears in
#             failure.
#             removing: _configtest.c _configtest.o
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
# ...
#                   |         ^~~~~~
#             In file included from /usr/include/python3.10/unicodeobject.h:1046,
#                              from /usr/include/python3.10/Python.h:83,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:1850:9: warning: ‘PyUnicode_AsUnicode’ is deprecated [-Wdeprecated-declarations]
#              1850 |         buflen = PyUnicode_GET_DATA_SIZE(self);
#                   |         ^~~~~~
#             In file included from /usr/include/python3.10/unicodeobject.h:1046,
#                              from /usr/include/python3.10/Python.h:83,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:1850:9: warning: ‘_PyUnicode_get_wstr_length’ is deprecated [-Wdeprecated-declarations]
#              1850 |         buflen = PyUnicode_GET_DATA_SIZE(self);
#                   |         ^~~~~~
#             In file included from /usr/include/python3.10/unicodeobject.h:1046,
#                              from /usr/include/python3.10/Python.h:83,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘float_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3311:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#                   |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                   |                           |
#                   |                           double
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3311:12: error: too few arguments to function ‘_Py_HashDouble’
#              3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#                   |            ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘cfloat_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3319:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3319 |     hashreal = _Py_HashDouble((double)
#                   |                               ^~~~~~~~
#                   |                               |
#                   |                               double
#              3320 |             (((PyC@name@ScalarObject *)obj)->obval).real);
#                   |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3319:16: error: too few arguments to function ‘_Py_HashDouble’
#              3319 |     hashreal = _Py_HashDouble((double)
#                   |                ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3325:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3325 |     hashimag = _Py_HashDouble((double)
#                   |                               ^~~~~~~~
#                   |                               |
#                   |                               double
#              3326 |             (((PyC@name@ScalarObject *)obj)->obval).imag);
#                   |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3325:16: error: too few arguments to function ‘_Py_HashDouble’
#              3325 |     hashimag = _Py_HashDouble((double)
#                   |                ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘longdouble_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3311:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#                   |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                   |                           |
#                   |                           double
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3311:12: error: too few arguments to function ‘_Py_HashDouble’
#              3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#                   |            ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘clongdouble_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3319:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3319 |     hashreal = _Py_HashDouble((double)
#                   |                               ^~~~~~~~
#                   |                               |
#                   |                               double
#              3320 |             (((PyC@name@ScalarObject *)obj)->obval).real);
#                   |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3319:16: error: too few arguments to function ‘_Py_HashDouble’
#              3319 |     hashreal = _Py_HashDouble((double)
#                   |                ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3325:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3325 |     hashimag = _Py_HashDouble((double)
#                   |                               ^~~~~~~~
#                   |                               |
#                   |                               double
#              3326 |             (((PyC@name@ScalarObject *)obj)->obval).imag);
#                   |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3325:16: error: too few arguments to function ‘_Py_HashDouble’
#              3325 |     hashimag = _Py_HashDouble((double)
#                   |                ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘half_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3341:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3341 |     return _Py_HashDouble(npy_half_to_double(((PyHalfScalarObject *)obj)->obval));
#                   |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                   |                           |
#                   |                           double
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3341:12: error: too few arguments to function ‘_Py_HashDouble’
#              3341 |     return _Py_HashDouble(npy_half_to_double(((PyHalfScalarObject *)obj)->obval));
#                   |            ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘longdouble_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3312:1: warning: control reaches end of non-void function [-Wreturn-type]
#              3312 | }
#                   | ^
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘float_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3312:1: warning: control reaches end of non-void function [-Wreturn-type]
#              3312 | }
#                   | ^
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘half_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3342:1: warning: control reaches end of non-void function [-Wreturn-type]
#              3342 | }
#                   | ^
#             error: Command "x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -Ibuild/src.linux-x86_64-3.1/numpy/core/src/umath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Inumpy/core/include -Ibuild/src.linux-x86_64-3.1/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/keos_angie/Música/music/myenv/include -I/usr/include/python3.10 -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -c build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.c -o build/temp.linux-x86_64-3.10/build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.o -MMD -MF build/temp.linux-x86_64-3.10/build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.o.d" failed with exit status 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: legacy-install-failure
#
#       × Encountered error while trying to install package.
#       ╰─> numpy
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for output from the failure.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import statistics
import json
import torch
import pytorch_lightning as pl
import re, nltk
import torch
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import plotly.express as px
import plotly.graph_objects as go

from pycaret.classification import  *

from statistics import mode
from unidecode import unidecode

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from torch import Tensor

from torch.nn import Module, Linear, Dropout, Sequential
from torch.nn.functional import cross_entropy, relu, sigmoid, binary_cross_entropy

from torch.optim import Adam, Optimizer
from torch.utils.data import Dataset, DataLoader, random_split

from pytorch_lightning import LightningModule, Trainer
from pytorch_lightning.loggers import CSVLogger
from pytorch_lightning.callbacks.early_stopping import EarlyStopping


from typing import Tuple, List, Callable

from numpy import nan, percentile, asarray
from numpy.typing import ArrayLike
from numpy.random import randn


from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# # Carga de Datos

# %%
df = pd.read_csv('Data_completa_enrriquecida.csv',  index_col=0)
df.head()
# Out:
#                                           Idioma lyrics_state  hasLetra  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt     en     complete       1.0
# Data/Letras/2-St.-Anger-Metallica.txt         en     complete       1.0
# Data/Letras/3-Speedin'-Rick-Ross.txt          en     complete       1.0
# Data/Letras/4-Bamboo-Banga-M.I.A..txt         en     complete       1.0
# Data/Letras/5-Die-MF-Die-Dope.txt             en     complete       1.0
#
#                                                                                       Lyrics  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  TranslationsEspañolTürkçePortuguêsItalianoहिन्...
# Data/Letras/2-St.-Anger-Metallica.txt      St. Anger Lyrics[Verse]\nSaint Anger 'round my...
# Data/Letras/3-Speedin'-Rick-Ross.txt       Speedin’ Lyrics[Intro: Rick Ross]\nLegendary\n...
# Data/Letras/4-Bamboo-Banga-M.I.A..txt      Bamboo Banga Lyrics[Intro]\nRoad runner, road ...
# Data/Letras/5-Die-MF-Die-Dope.txt          Die MF Die Lyrics[Intro]\nDie!\n\n[Verse 1]\nI...
#
#                                                                                Lyrics_proces  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  cause feel tired left left feel weak feel weak...
# Data/Letras/2-St.-Anger-Metallica.txt      saint anger round neck saint anger round neck ...
# Data/Letras/3-Speedin'-Rick-Ross.txt       legendary runners know trilla dollar count acc...
# Data/Letras/4-Bamboo-Banga-M.I.A..txt      road runner road runner going miles hour road ...
# Data/Letras/5-Die-MF-Die-Dope.txt          die need forgiveness need hate need acceptance...
#
#                                                                songId  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  till-i-collapse-eminem.txt
# Data/Letras/2-St.-Anger-Metallica.txt         st.-anger-metallica.txt
# Data/Letras/3-Speedin'-Rick-Ross.txt            speedin-rick-ross.txt
# Data/Letras/4-Bamboo-Banga-M.I.A..txt         bamboo-banga-m.i.a..txt
# Data/Letras/5-Die-MF-Die-Dope.txt                 die-mf-die-dope.txt
#
#                                                                       track_uri  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  spotify:track:4xkOaSrkexMciUUogZKVTS
# Data/Letras/2-St.-Anger-Metallica.txt      spotify:track:3fOc9x06lKJBhz435mInlH
# Data/Letras/3-Speedin'-Rick-Ross.txt       spotify:track:3Y96xd4Ce0J47dcalLrEC8
# Data/Letras/4-Bamboo-Banga-M.I.A..txt      spotify:track:6tqFC1DIOphJkCwrjVzPmg
# Data/Letras/5-Die-MF-Die-Dope.txt          spotify:track:5bU4KX47KqtDKKaLM4QCzh
#
#                                                 track_name  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  Till I Collapse
# Data/Letras/2-St.-Anger-Metallica.txt            St. Anger
# Data/Letras/3-Speedin'-Rick-Ross.txt              Speedin'
# Data/Letras/4-Bamboo-Banga-M.I.A..txt         Bamboo Banga
# Data/Letras/5-Die-MF-Die-Dope.txt               Die MF Die
#
#                                                                       artist_uri  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  spotify:artist:7dGJo4pcD2V6oG8kP0tJRR
# Data/Letras/2-St.-Anger-Metallica.txt      spotify:artist:2ye2Wgw4gimLv2eAKyk1NB
# Data/Letras/3-Speedin'-Rick-Ross.txt       spotify:artist:1sBkRIssrMs1AbVkOJbc7a
# Data/Letras/4-Bamboo-Banga-M.I.A..txt      spotify:artist:0QJIPDAEDILuo8AIq3pMuU
# Data/Letras/5-Die-MF-Die-Dope.txt          spotify:artist:7fWgqc4HJi3pcHhK8hKg2p
#
#                                                                                  artist_info  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  {'external_urls': {'spotify': 'https://open.sp...
# Data/Letras/2-St.-Anger-Metallica.txt      {'external_urls': {'spotify': 'https://open.sp...
# Data/Letras/3-Speedin'-Rick-Ross.txt       {'external_urls': {'spotify': 'https://open.sp...
# Data/Letras/4-Bamboo-Banga-M.I.A..txt      {'external_urls': {'spotify': 'https://open.sp...
# Data/Letras/5-Die-MF-Die-Dope.txt          {'external_urls': {'spotify': 'https://open.sp...
#
#                                            ... dominance_tags  \
# Letra                                      ...
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  ...       5.690625
# Data/Letras/2-St.-Anger-Metallica.txt      ...       5.427250
# Data/Letras/3-Speedin'-Rick-Ross.txt       ...       5.490000
# Data/Letras/4-Bamboo-Banga-M.I.A..txt      ...       5.691357
# Data/Letras/5-Die-MF-Die-Dope.txt          ...       5.441765
#
#                                                                            mbid  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  cab93def-26c5-4fb0-bedd-26ec4c1619e1
# Data/Letras/2-St.-Anger-Metallica.txt      727a2529-7ee8-4860-aef6-7959884895cb
# Data/Letras/3-Speedin'-Rick-Ross.txt                                        NaN
# Data/Letras/4-Bamboo-Banga-M.I.A..txt      99dd2c8c-e7c1-413e-8ea4-4497a00ffa18
# Data/Letras/5-Die-MF-Die-Dope.txt          b9eb3484-5e0e-4690-ab5a-ca91937032a5
#
#                                                        spotify_id    genre  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  4xkOaSrkexMciUUogZKVTS      rap
# Data/Letras/2-St.-Anger-Metallica.txt      3fOc9x06lKJBhz435mInlH    metal
# Data/Letras/3-Speedin'-Rick-Ross.txt       3Y96xd4Ce0J47dcalLrEC8      rap
# Data/Letras/4-Bamboo-Banga-M.I.A..txt      6tqFC1DIOphJkCwrjVzPmg  hip-hop
# Data/Letras/5-Die-MF-Die-Dope.txt          5bU4KX47KqtDKKaLM4QCzh    metal
#
#                                            cuadrante  cuadReal  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt          3         2
# Data/Letras/2-St.-Anger-Metallica.txt              3         2
# Data/Letras/3-Speedin'-Rick-Ross.txt               3         2
# Data/Letras/4-Bamboo-Banga-M.I.A..txt              3         1
# Data/Letras/5-Die-MF-Die-Dope.txt                  3         1
#
#                                                                  lexicones  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  [0. 2. 0. 0. 0. 2. 6. 0. 0. 2.]
# Data/Letras/2-St.-Anger-Metallica.txt      [0. 6. 0. 0. 0. 6. 0. 0. 0. 0.]
# Data/Letras/3-Speedin'-Rick-Ross.txt       [0. 2. 0. 0. 0. 2. 0. 0. 0. 0.]
# Data/Letras/4-Bamboo-Banga-M.I.A..txt      [0. 0. 0. 0. 0. 0. 4. 0. 0. 0.]
# Data/Letras/5-Die-MF-Die-Dope.txt          [0. 1. 0. 0. 0. 1. 0. 0. 0. 0.]
#
#                                                                                    emociones  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  ['anticipation', 'negative', 'positive', 'trust']
# Data/Letras/2-St.-Anger-Metallica.txt                           ['anticipation', 'negative']
# Data/Letras/3-Speedin'-Rick-Ross.txt                            ['anticipation', 'negative']
# Data/Letras/4-Bamboo-Banga-M.I.A..txt                                           ['positive']
# Data/Letras/5-Die-MF-Die-Dope.txt                               ['anticipation', 'negative']
#
#                                                  emocionesLetra  \
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt  ['3', '2', '1', '3']
# Data/Letras/2-St.-Anger-Metallica.txt                ['3', '2']
# Data/Letras/3-Speedin'-Rick-Ross.txt                 ['3', '2']
# Data/Letras/4-Bamboo-Banga-M.I.A..txt                     ['1']
# Data/Letras/5-Die-MF-Die-Dope.txt                    ['3', '2']
#
#                                            emocion_mas_comun
# Letra
# Data/Letras/1-'Till-I-Collapse-Eminem.txt                  3
# Data/Letras/2-St.-Anger-Metallica.txt                      3
# Data/Letras/3-Speedin'-Rick-Ross.txt                       3
# Data/Letras/4-Bamboo-Banga-M.I.A..txt                      1
# Data/Letras/5-Die-MF-Die-Dope.txt                          3
#
# [5 rows x 49 columns]

# %% [markdown]
# ## preprocesamiento

# %%
df = df[['Idioma', 'lyrics_state', 'hasLetra', 'Lyrics', 'Lyrics_proces',
       'songId', 'track_uri', 'emocion_mas_comun', 'cuadrante',
       'cuadReal']]

# %%
df.Idioma.value_counts()
# Out:
# en              23460
# es                387
# fr                239
# pt                214
# de                183
# it                102
# sv                 36
# nl                 36
# la                 34
# pl                 28
# da                 19
# no                 15
# romanization       10
# ko                  9
# tr                  6
# id                  6
# ja                  4
# ca                  3
# ro                  3
# hr                  3
# ar                  3
# fi                  3
# xh                  2
# sq                  2
# eu                  2
# af                  2
# sw                  2
# ln                  2
# gd                  2
# ga                  2
# ru                  2
# ia                  1
# el                  1
# sco                 1
# zu                  1
# ms                  1
# ss                  1
# ak                  1
# lv                  1
# tl                  1
# gl                  1
# bs                  1
# wo                  1
# ve                  1
# yo                  1
# sm                  1
# eo                  1
# fy                  1
# lb                  1
# is                  1
# et                  1
# su                  1
# co                  1
# lt                  1
# war                 1
# hu                  1
# sk                  1
# sl                  1
# Name: Idioma, dtype: int64

# %%
df = df[df["Idioma"]=='en']

# %%
corpus = df.Lyrics_proces

# %%
df.shape
# Out:
# (23460, 10)

# %% [markdown]
# # Extracción de Características

# %%
corpus_df = df[['Lyrics', 'cuadReal']]
corpus_df = corpus_df.drop_duplicates()
corpus_df = corpus_df.reset_index()
corpus_df = corpus_df[['Lyrics', 'cuadReal']]

# %%
s = setup(corpus_df, 
	target = 'cuadReal', 
	session_id = 123, 
	text_features_method= 'tf-idf', 
	text_features = ['Lyrics'], 
	ignore_features = ['Letra'],
	fix_imbalance = True
)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s = setup(corpus_df,
#       2 	target = 'cuadReal',
#       3 	session_id = 123,
#       4 	text_features_method= 'tf-idf',
#       5 	text_features = ['Lyrics'],
#       6 	ignore_features = ['Letra'],
#       7 	fix_imbalance = True
#       8 )
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/pycaret/classification/functional.py:602, in setup(data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     600 exp = _EXPERIMENT_CLASS()
#     601 set_current_experiment(exp)
# --> 602 return exp.setup(
#     603     data=data,
#     604     data_func=data_func,
#     605     target=target,
#     606     index=index,
#     607     train_size=train_size,
#     608     test_data=test_data,
#     609     ordinal_features=ordinal_features,
#     610     numeric_features=numeric_features,
#     611     categorical_features=categorical_features,
#     612     date_features=date_features,
#     613     text_features=text_features,
#     614     ignore_features=ignore_features,
#     615     keep_features=keep_features,
#     616     preprocess=preprocess,
#     617     create_date_columns=create_date_columns,
#     618     imputation_type=imputation_type,
#     619     numeric_imputation=numeric_imputation,
#     620     categorical_imputation=categorical_imputation,
#     621     iterative_imputation_iters=iterative_imputation_iters,
#     622     numeric_iterative_imputer=numeric_iterative_imputer,
#     623     categorical_iterative_imputer=categorical_iterative_imputer,
#     624     text_features_method=text_features_method,
#     625     max_encoding_ohe=max_encoding_ohe,
#     626     encoding_method=encoding_method,
#     627     rare_to_value=rare_to_value,
#     628     rare_value=rare_value,
#     629     polynomial_features=polynomial_features,
#     630     polynomial_degree=polynomial_degree,
#     631     low_variance_threshold=low_variance_threshold,
#     632     group_features=group_features,
#     633     group_names=group_names,
#     634     drop_groups=drop_groups,
#     635     remove_multicollinearity=remove_multicollinearity,
#     636     multicollinearity_threshold=multicollinearity_threshold,
#     637     bin_numeric_features=bin_numeric_features,
#     638     remove_outliers=remove_outliers,
#     639     outliers_method=outliers_method,
#     640     outliers_threshold=outliers_threshold,
#     641     fix_imbalance=fix_imbalance,
#     642     fix_imbalance_method=fix_imbalance_method,
#     643     transformation=transformation,
#     644     transformation_method=transformation_method,
#     645     normalize=normalize,
#     646     normalize_method=normalize_method,
#     647     pca=pca,
#     648     pca_method=pca_method,
#     649     pca_components=pca_components,
#     650     feature_selection=feature_selection,
#     651     feature_selection_method=feature_selection_method,
#     652     feature_selection_estimator=feature_selection_estimator,
#     653     n_features_to_select=n_features_to_select,
#     654     custom_pipeline=custom_pipeline,
#     655     custom_pipeline_position=custom_pipeline_position,
#     656     data_split_shuffle=data_split_shuffle,
#     657     data_split_stratify=data_split_stratify,
#     658     fold_strategy=fold_strategy,
#     659     fold=fold,
#     660     fold_shuffle=fold_shuffle,
#     661     fold_groups=fold_groups,
#     662     n_jobs=n_jobs,
#     663     use_gpu=use_gpu,
#     664     html=html,
#     665     session_id=session_id,
#     666     system_log=system_log,
#     667     log_experiment=log_experiment,
#     668     experiment_name=experiment_name,
#     669     experiment_custom_tags=experiment_custom_tags,
#     670     log_plots=log_plots,
#     671     log_profile=log_profile,
#     672     log_data=log_data,
#     673     verbose=verbose,
#     674     memory=memory,
#     675     profile=profile,
#     676     profile_kwargs=profile_kwargs,
#     677 )
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/pycaret/classification/oop.py:900, in ClassificationExperiment.setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     897 if ("placeholder", None) in self.pipeline.steps and len(self.pipeline) > 1:
#     898     self.pipeline.steps.remove(("placeholder", None))
# --> 900 self.pipeline.fit(self.X_train, self.y_train)
#     902 self.logger.info("Finished creating preprocessing pipeline.")
#     903 self.logger.info(f"Pipeline: {self.pipeline}")
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/pycaret/internal/pipeline.py:255, in Pipeline.fit(self, X, y, **fit_params)
#     253 def fit(self, X=None, y=None, **fit_params):
#     254     fit_params_steps = self._check_fit_params(**fit_params)
# --> 255     X, y, _ = self._fit(X, y, **fit_params_steps)
#     257     with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     258         if self._final_estimator != "passthrough":
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/pycaret/internal/pipeline.py:238, in Pipeline._fit(self, X, y, **fit_params_steps)
#     230     # Fit or load the current transformer from cache
#     231     fitted_transformer = self._memory_fit(
#     232         transformer=cloned,
#     233         X=X,
#    (...)
#     236         **fit_params_steps.get(name, {}),
#     237     )
# --> 238     X, y = self._memory_transform(
#     239         transformer=fitted_transformer,
#     240         X=X,
#     241         y=y,
#     242     )
#     244 # Replace the transformer of the step with the fitted
#     245 # transformer (necessary when loading from the cache)
#     246 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/joblib/memory.py:594, in MemorizedFunc.__call__(self, *args, **kwargs)
#     593 def __call__(self, *args, **kwargs):
# --> 594     return self._cached_call(args, kwargs)[0]
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/pycaret/internal/memory.py:398, in FastMemorizedFunc._cached_call(self, args, kwargs, shelving)
#     395 if must_call:
#     396     # PYCARET CHANGES
#     397     self._cached_output_identifiers = func_id, args_id
# --> 398     out, metadata = self.call(*args, **kwargs)
#     399     if self.mmap_mode is not None and metadata is not None:
#     400         # PYCARET CHANGES END
#     401         # Memmap the output at the first call to be consistent with
#     402         # later calls
#     403         if self._verbose:
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/pycaret/internal/memory.py:309, in FastMemorizedFunc.call(self, *args, **kwargs)
#     307 # PYCARET CHANGES
#     308 func_start_time = time.monotonic()
# --> 309 output = self.func(*args, **kwargs)
#     310 func_duration = time.monotonic() - func_start_time
#     311 if func_duration >= self.min_time_to_cache:
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/pycaret/internal/pipeline.py:77, in _transform_one(transformer, X, y)
#      75 if "y" in signature(transformer.transform).parameters:
#      76     args.append(y)
# ---> 77 output = transformer.transform(*args)
#      79 if isinstance(output, tuple):
#      80     X, y = output[0], output[1]
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/pycaret/internal/preprocess/transformers.py:254, in TransformerWrapper.transform(self, X, y)
#     251     elif "X" not in transform_params:
#     252         return X, y
# --> 254 output = self.transformer.transform(*args)
#     256 # Transform can return X, y or both
#     257 if isinstance(output, tuple):
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/pycaret/internal/preprocess/transformers.py:358, in EmbedTextFeatures.transform(self, X, y)
#     356 def transform(self, X, y=None):
#     357     for col in X:
# --> 358         data = self.estimators_[col].transform(X[col]).toarray()
#     359         columns = [
#     360             f"{col}_{word}"
#     361             for word in self.estimators_[col].get_feature_names_out()
#     362         ]
#     364         # Merge the new columns with the dataset
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/scipy/sparse/_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File ~/Música/music/myenv/lib/python3.10/site-packages/scipy/sparse/_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 30.6 GiB for an array with shape (15135, 271453) and data type float64

# %% [markdown]
# ## Tfidf

# %%
vectorizer = TfidfVectorizer(
    sublinear_tf=True, min_df=70, max_df=0.6
    )

# %%
tfidf_matrix = vectorizer.fit_transform(corpus)

# %%
joblib.dump(tfidf_matrix, "vect_tfidf.joblib")
# Out:
# ['vect_tfidf.joblib']

# %%
tfidf_matrix = joblib.load("vect_tfidf.joblib")

# %% [markdown]
# ## LSA

# %%
# Aplicar LSA con TruncatedSVD
lsa_model = TruncatedSVD(n_components=5)  # Especifica el número de componentes deseados
lsa_matrix = lsa_model.fit_transform(tfidf_matrix)

# %%
joblib.dump(lsa_matrix, "lsa_matrix.joblib")
# Out:
# ['lsa_matrix.joblib']

# %%
lsa_matrix = joblib.load("lsa_matrix.joblib")

# %% [markdown]
# # Dividir datos

# %%
class PersonalityDataset(Dataset):
    def __init__(self, features: ArrayLike, labels: ArrayLike):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.int64)

    def __len__(self) -> int:
        return self.features.shape[0]

    def __getitem__(self, idx: int) -> Tuple[Tensor, Tensor]:
        return self.features[idx], self.labels[idx]

# %%
features = vect.transform(corpus).toarray()
labels = df.cuadReal.to_numpy()

# %%
labels.shape
# Out:
# (23460,)

# %%
features.shape
# Out:
# (23460, 38721)

# %%
ds = PersonalityDataset(
        features = features, labels=labels
        ) 
train_ds, val_ds, test_ds = random_split(ds, [0.6, 0.2, 0.2])

# %%
train_dl = DataLoader(train_ds, batch_size=1024) 
val_dl = DataLoader(val_ds, batch_size=512) 
test_dl = DataLoader(test_ds, batch_size=512)

# %%
(train_ds.dataset.features).shape, train_ds.dataset.labels.shape
# Out:
# (torch.Size([23460, 38721]), torch.Size([23460]))

# %% [markdown]
# # Modelamiento

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(max_depth=15, random_state=0)

model.fit(train_ds.dataset.features, train_ds.dataset.labels)
predicted = model.predict(train_ds.dataset.features)

print(f'El score del modelo  es: {model.score(train_ds.dataset.features, train_ds.dataset.labels)}')
# Out:
# El score del modelo  es: 0.55

# %% [markdown]
# ## árboles de decisión

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

model = DecisionTreeClassifier(max_depth=5)

clf = model.fit(train_ds.dataset.features, train_ds.dataset.labels) 
predicted = model.predict(train_ds.dataset.features)

print(f'El score del modelo  es: {model.score(train_ds.dataset.features, train_ds.dataset.labels)}')
# Out:
# El score del modelo  es: 0.41445012787723784

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=10)

model.fit(train_ds.dataset.features, train_ds.dataset.labels)
predicted = model.predict(train_ds.dataset.features)

print(f'El score del modelo  es: {model.score(train_ds.dataset.features, train_ds.dataset.labels)}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-cea683aeb7bd> in <cell line: 6>()
#       4
#       5 model.fit(train_ds.dataset.features, train_ds.dataset.labels)
# ----> 6 predicted = model.predict(train_ds.dataset.features)
#       7
#       8 print(f'El score del modelo  es: {model.score(train_ds.dataset.features, train_ds.dataset.labels)}')
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     232             # In that case, we do not need the distances to perform
#     233             # the weighting so we do not compute them.
# --> 234             neigh_ind = self.kneighbors(X, return_distance=False)
#     235             neigh_dist = None
#     236         else:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     822         )
#     823         if use_pairwise_distances_reductions:
# --> 824             results = ArgKmin.compute(
#     825                 X=X,
#     826                 Y=self._fit_X,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py in compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     287
#     288         if X.dtype == Y.dtype == np.float32:
# --> 289             return ArgKmin32.compute(
#     290                 X=X,
#     291                 Y=Y,
#
# sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin32.compute()
#
# /usr/local/lib/python3.10/dist-packages/threadpoolctl.py in __exit__(self, type, value, traceback)
#     169         return self
#     170
# --> 171     def __exit__(self, type, value, traceback):
#     172         self.restore_original_limits()
#     173
#
# KeyboardInterrupt:

# %% [markdown]
# ## regresión logística

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='lbfgs', max_iter=10)

model.fit(train_ds.dataset.features, train_ds.dataset.labels)
predicted = model.predict(train_ds.dataset.features)

print(f'El score del modelo es: {model.score(train_ds.dataset.features, train_ds.dataset.labels)}')

# %% [markdown]
# balancear -> smote (data aumentation)
# revisar las proporciones de los cuadrantes
# usar modelo preentrenado
# probar random forest

# %%
Batch = Tuple[Tensor, Tensor]

class Dense(Module):
    def __init__(
        self,
        in_features: int,
        out_features: int,
        activation: Callable,
        dropout: float,
        ):
        super(Dense, self).__init__()
        self.layer = Linear(in_features=in_features, out_features=out_features)
        self.dropout = Dropout(p=dropout)
        self.activation = activation
    
    def forward(self, x: Tensor) -> Tensor:
        return self.activation(self.dropout(self.layer(x)))

class MLP(LightningModule):
    def __init__(
            self, n_units: List[int], activations: List[Callable],
            dropout: float
            ):
        super(MLP, self).__init__()
        self.layers = Sequential(
            *(
                Dense(
                    in_features=ins,
                    out_features=outs,
                    activation=act,
                    dropout=dropout
                    )
                for ins, outs, act in zip(
                    n_units,
                    n_units[1:],
                    activations
                )
            )
        )
    
    def forward(self, x: Tensor) -> Tensor:
        return self.layers(x)

    def configure_optimizers(self) -> Optimizer:
        return Adam(self.parameters(), lr=1e-4)

    def training_step(
        self, train_batch: Batch, batch_idx: int
        ) -> Tensor:
        features, labels = train_batch
        y_pred = self.forward(features)
        loss_val = cross_entropy(y_pred, labels)
        self.log("train_loss", loss_val)
        return loss_val
    
    def validation_step(
        self, val_batch: Batch, batch_idx: int
        ):
        features, labels = val_batch
        y_pred = self.forward(features)
        loss_val = cross_entropy(y_pred, labels)
        self.log("val_loss", loss_val)

# %%
logger = CSVLogger(save_dir="logs/", name="losses.csv")
trainer = Trainer(
    max_epochs=300,
    logger=logger, log_every_n_steps=10,
    callbacks=[
        EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=20),
        ]
)

# %%
linear = lambda x: x
model = MLP(
    n_units=[features.shape[1], 16],
    activations=[linear],
    dropout=0.0
    )

# %%
trainer.fit(model, train_dl, val_dl)

# %% [markdown]
# # Evaluación

# %%
df = pd.read_csv("logs/losses.csv/version_0/metrics.csv")
df_train = (
    df
    .filter(["epoch", "train_loss"])
    .dropna()
    .groupby("epoch")
    .agg({"train_loss": "mean"})
)
df_test = (
    df
    .filter(["epoch", "val_loss"])
    .dropna()
    .groupby("epoch")
    .agg({"val_loss": "mean"})
)   

df = df_train.join(df_test, on="epoch").reset_index()

# %%
fig = (
    px.line(df, x="epoch", y=["train_loss", "val_loss"])
)
fig.show()

# %%
metric = []
for features_batch, labels_batch in test_dl:
    y_pred = torch.argmax(model(features_batch), dim=1)
    metric.append(y_pred == labels_batch)

# %%
metric = torch.concat(metric) 
print(metric.float().mean())
